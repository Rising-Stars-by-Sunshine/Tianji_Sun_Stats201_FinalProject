# %% [markdown]
# *   Computing Platforms: Set up the Workspace for Machine Learning Projects.  https://ms.pubpub.org/pub/computing
# *  Machine Learning for Predictions. https://ms.pubpub.org/pub/ml-prediction
# * Machine Learning Packages: https://scikit-learn.org/stable/

# %% [markdown]
# # Part I: Import and Inspect Data

# %%
import pandas as pd
import numpy as np
import random
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('./foreign_investment.csv')
df.head()
# Out:
#    Year       FDI           GDP       VALUE       SAVING  SAVING_RATE
# 0  1980  0.029820  191149211648  3822984233  67495989500    35.310629
# 1  1981  0.135296  195866378240  3917327565  65779071687    33.583646
# 2  1982  0.209664  205089701888  4101794038  68568971469    33.433649
# 3  1983  0.275699  230686752768  4613735055  75085127996    32.548522
# 4  1984  0.483946  259946512384  5198930248  88994888904    34.235846

# %% [markdown]
# # Part II: Prepare the Y varible for Regression

# %% [markdown]
# ## 2.1. Write functions to calculte the Y variable for Regression
#
# *(skip the step if the Y variable already exists)*

# %%
df['iyoy'] = df['FDI']-df['FDI'].shift(1)
df['syoy'] = df['SAVING_RATE']-df['SAVING_RATE'].shift(1)
df.head()
# Out:
#    Year       FDI           GDP       VALUE       SAVING  SAVING_RATE  \
# 0  1980  0.029820  191149211648  3822984233  67495989500    35.310629
# 1  1981  0.135296  195866378240  3917327565  65779071687    33.583646
# 2  1982  0.209664  205089701888  4101794038  68568971469    33.433649
# 3  1983  0.275699  230686752768  4613735055  75085127996    32.548522
# 4  1984  0.483946  259946512384  5198930248  88994888904    34.235846
#
#        iyoy      syoy
# 0       NaN       NaN
# 1  0.105477 -1.726983
# 2  0.074368 -0.149997
# 3  0.066034 -0.885127
# 4  0.208247  1.687325

# %% [markdown]
# ## 2.2. Make Sure that the Data Type of Y is "numeric"

# %%
df.dtypes
# Out:
# Year             int64
# FDI            float64
# GDP              int64
# VALUE            int64
# SAVING           int64
# SAVING_RATE    float64
# iyoy           float64
# syoy           float64
# dtype: object

# %% [markdown]
# # Part III: Prepare the Y variable for Classification

# %% [markdown]
# reference:
#
# https://datatofish.com/if-condition-in-pandas-dataframe/ *italicized text*

# %%
#@title Define the Congestion Threshold
cut = 0.0 #@param {type:"number"}

# %%
df['icongested'] = df['iyoy'] >= cut
df['scongested'] = df['syoy'] >= cut
df.head(10)
# Out:
#    Year       FDI           GDP       VALUE        SAVING  SAVING_RATE  \
# 0  1980  0.029820  191149211648  3822984233   67495989500    35.310629
# 1  1981  0.135296  195866378240  3917327565   65779071687    33.583646
# 2  1982  0.209664  205089701888  4101794038   68568971469    33.433649
# 3  1983  0.275699  230686752768  4613735055   75085127996    32.548522
# 4  1984  0.483946  259946512384  5198930248   88994888904    34.235846
# 5  1985  0.536047  309488025600  6189760512  108101540816    34.929151
# 6  1986  0.623425  300758106112  6015162122  105661789478    35.131818
# 7  1987  0.847703  272972972032  5459459441  101593543706    37.217437
# 8  1988  1.022559  312353619968  6247072399  118333692506    37.884527
# 9  1989  0.975650  347768061952  6955361239  124211785334    35.716847
#
#        iyoy      syoy  icongested  scongested
# 0       NaN       NaN       False       False
# 1  0.105477 -1.726983        True       False
# 2  0.074368 -0.149997        True       False
# 3  0.066034 -0.885127        True       False
# 4  0.208247  1.687325        True        True
# 5  0.052101  0.693305        True        True
# 6  0.087378  0.202666        True        True
# 7  0.224278  2.085619        True        True
# 8  0.174856  0.667090        True        True
# 9 -0.046909 -2.167681       False       False

# %%
df.loc[(df['iyoy'] >= cut), 'icongested'] = 1
df.loc[(df['iyoy'] <cut), 'icongested'] = 0
df.loc[(df['syoy'] >= cut), 'scongested'] = 1
df.loc[(df['syoy'] <cut), 'scongested'] = 0
df.head(10)
# Out:
#    Year       FDI           GDP       VALUE        SAVING  SAVING_RATE  \
# 0  1980  0.029820  191149211648  3822984233   67495989500    35.310629
# 1  1981  0.135296  195866378240  3917327565   65779071687    33.583646
# 2  1982  0.209664  205089701888  4101794038   68568971469    33.433649
# 3  1983  0.275699  230686752768  4613735055   75085127996    32.548522
# 4  1984  0.483946  259946512384  5198930248   88994888904    34.235846
# 5  1985  0.536047  309488025600  6189760512  108101540816    34.929151
# 6  1986  0.623425  300758106112  6015162122  105661789478    35.131818
# 7  1987  0.847703  272972972032  5459459441  101593543706    37.217437
# 8  1988  1.022559  312353619968  6247072399  118333692506    37.884527
# 9  1989  0.975650  347768061952  6955361239  124211785334    35.716847
#
#        iyoy      syoy icongested scongested
# 0       NaN       NaN      False      False
# 1  0.105477 -1.726983          1          0
# 2  0.074368 -0.149997          1          0
# 3  0.066034 -0.885127          1          0
# 4  0.208247  1.687325          1          1
# 5  0.052101  0.693305          1          1
# 6  0.087378  0.202666          1          1
# 7  0.224278  2.085619          1          1
# 8  0.174856  0.667090          1          1
# 9 -0.046909 -2.167681          0          0

# %% [markdown]
# # 3.3. Method 3: Lambda function

# %%
df['icongested'] = df['iyoy'].apply(lambda x: 1 if x>= cut else 0)
df['scongested'] = df['syoy'].apply(lambda x: 1 if x>= cut else 0)
df.head(10)
# Out:
#    Year       FDI           GDP       VALUE        SAVING  SAVING_RATE  \
# 0  1980  0.029820  191149211648  3822984233   67495989500    35.310629
# 1  1981  0.135296  195866378240  3917327565   65779071687    33.583646
# 2  1982  0.209664  205089701888  4101794038   68568971469    33.433649
# 3  1983  0.275699  230686752768  4613735055   75085127996    32.548522
# 4  1984  0.483946  259946512384  5198930248   88994888904    34.235846
# 5  1985  0.536047  309488025600  6189760512  108101540816    34.929151
# 6  1986  0.623425  300758106112  6015162122  105661789478    35.131818
# 7  1987  0.847703  272972972032  5459459441  101593543706    37.217437
# 8  1988  1.022559  312353619968  6247072399  118333692506    37.884527
# 9  1989  0.975650  347768061952  6955361239  124211785334    35.716847
#
#        iyoy      syoy  icongested  scongested
# 0       NaN       NaN           0           0
# 1  0.105477 -1.726983           1           0
# 2  0.074368 -0.149997           1           0
# 3  0.066034 -0.885127           1           0
# 4  0.208247  1.687325           1           1
# 5  0.052101  0.693305           1           1
# 6  0.087378  0.202666           1           1
# 7  0.224278  2.085619           1           1
# 8  0.174856  0.667090           1           1
# 9 -0.046909 -2.167681           0           0

# %% [markdown]
# ## 3.2. Method 2: Cut function

# %% [markdown]
# reference:
#
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.cut.html

# %%
import numpy as np
 
icongested = pd.cut(df['iyoy'], bins=[-1,0,1], labels=[0,1]) #might have problems at boundaries
df.insert(3, 'icongested2',icongested)

# %%
df.head(10)
# Out:
#    Year       FDI           GDP icongested2       VALUE        SAVING  \
# 0  1980  0.029820  191149211648         NaN  3822984233   67495989500
# 1  1981  0.135296  195866378240           1  3917327565   65779071687
# 2  1982  0.209664  205089701888           1  4101794038   68568971469
# 3  1983  0.275699  230686752768           1  4613735055   75085127996
# 4  1984  0.483946  259946512384           1  5198930248   88994888904
# 5  1985  0.536047  309488025600           1  6189760512  108101540816
# 6  1986  0.623425  300758106112           1  6015162122  105661789478
# 7  1987  0.847703  272972972032           1  5459459441  101593543706
# 8  1988  1.022559  312353619968           1  6247072399  118333692506
# 9  1989  0.975650  347768061952           0  6955361239  124211785334
#
#    SAVING_RATE      iyoy      syoy  icongested  scongested
# 0    35.310629       NaN       NaN           0           0
# 1    33.583646  0.105477 -1.726983           1           0
# 2    33.433649  0.074368 -0.149997           1           0
# 3    32.548522  0.066034 -0.885127           1           0
# 4    34.235846  0.208247  1.687325           1           1
# 5    34.929151  0.052101  0.693305           1           1
# 6    35.131818  0.087378  0.202666           1           1
# 7    37.217437  0.224278  2.085619           1           1
# 8    37.884527  0.174856  0.667090           1           1
# 9    35.716847 -0.046909 -2.167681           0           0

# %% [markdown]
# # Part III: Create the X variables

# %% [markdown]
# ## 3.1. Shift the Y to get past values

# %% [markdown]
# reference:
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.shift.html

# %% [markdown]
# # Part IV Train and Test Split

# %%
from sklearn.model_selection import TimeSeriesSplit

# %%
tss = TimeSeriesSplit()
for train_idx, test_idx in tss.split(df):
    pass

# %%
train_df = df.filter(items=train_idx, axis=0)
test_df =  df.filter(items=test_idx, axis=0)
train_df.head()
# Out:
#    Year       FDI           GDP icongested2       VALUE       SAVING  \
# 0  1980  0.029820  191149211648         NaN  3822984233  67495989500
# 1  1981  0.135296  195866378240           1  3917327565  65779071687
# 2  1982  0.209664  205089701888           1  4101794038  68568971469
# 3  1983  0.275699  230686752768           1  4613735055  75085127996
# 4  1984  0.483946  259946512384           1  5198930248  88994888904
#
#    SAVING_RATE      iyoy      syoy  icongested  scongested
# 0    35.310629       NaN       NaN           0           0
# 1    33.583646  0.105477 -1.726983           1           0
# 2    33.433649  0.074368 -0.149997           1           0
# 3    32.548522  0.066034 -0.885127           1           0
# 4    34.235846  0.208247  1.687325           1           1

# %%
test_df.head()
# Out:
#     Year       FDI             GDP icongested2         VALUE         SAVING  \
# 35  2015  2.192182  11061553004544           0  221231060091  5089321787006
# 36  2016  1.555642  11233276198912           0  224665523978  5050623559476
# 37  2017  1.349133  12310409117696           0  246208182354  5555981442269
# 38  2018  1.693905  13894817939456           1  277896358789  6244652135107
# 39  2019  1.310719  14279937884160           0  285598757683  6280520248263
#
#     SAVING_RATE      iyoy      syoy  icongested  scongested
# 35    46.009107 -0.367052 -1.465948           0           0
# 36    44.961269 -0.636539 -1.047838           0           0
# 37    45.132387 -0.206509  0.171117           0           1
# 38    44.942310  0.344773 -0.190077           1           0
# 39    43.981426 -0.383187 -0.960884           0           0

# %% [markdown]
# # Part IV Prepare the Train and Test Data for Classification and Regression

# %%
df_C =df[['scongested','iyoy']]
df_R =df[['syoy','iyoy']]

# %%
# please complete the code on your own
for train_idx, test_idx in tss.split(df_C):
    pass
df_C_train = df_C.filter(items=train_idx, axis=0)
df_C_test =  df_C.filter(items=test_idx, axis=0)
df_C_train.head()
# Out:
#    scongested      iyoy
# 0           0       NaN
# 1           0  0.105477
# 2           0  0.074368
# 3           0  0.066034
# 4           1  0.208247

# %%
df_C_test.head()
# Out:
#     scongested      iyoy
# 35           0 -0.367052
# 36           0 -0.636539
# 37           1 -0.206509
# 38           0  0.344773
# 39           0 -0.383187

# %%
# please complete the code on your own
for train_idx, test_idx in tss.split(df_R):
    pass
df_R_train = df_R.filter(items=train_idx, axis=0)
df_R_test =  df_R.filter(items=test_idx, axis=0)
df_R_train.head()
# Out:
#        syoy      iyoy
# 0       NaN       NaN
# 1 -1.726983  0.105477
# 2 -0.149997  0.074368
# 3 -0.885127  0.066034
# 4  1.687325  0.208247

# %%
df_R_test.head()
# Out:
#         syoy      iyoy
# 35 -1.465948 -0.367052
# 36 -1.047838 -0.636539
# 37  0.171117 -0.206509
# 38 -0.190077  0.344773
# 39 -0.960884 -0.383187

# %%
#export and save the data to the processed data folder, please complete the code on your own
df_C_train.to_csv('df3_C_train.csv')
df_C_test.to_csv('df3_C_test.csv')

# %%
df_R_train.to_csv('df3_R_train.csv')
df_R_test.to_csv('df3_R_test.csv')
